# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import matplotlib as mpl
import matplotlib.pyplot as plt
# %pylab inline
# %matplotlib inline
import seaborn as sns
import re
import matplotlib
matplotlib.style.use('ggplot')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
project = pd.read_csv("multipleChoiceResponses.csv",encoding='ISO-8859-1')
#project
# Out:
# C:\Users\MUSA\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (31,83,86,87,98,99,109,116,123,124,127,129,130,164) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
project.head(3)
# Out:
#                                         GenderSelect        Country   Age  \
# 0  Non-binary, genderqueer, or gender non-conforming            NaN   NaN
# 1                                             Female  United States  30.0
# 2                                               Male         Canada  28.0
#
#                      EmploymentStatus StudentStatus LearningDataScience  \
# 0                  Employed full-time           NaN                 NaN
# 1  Not employed, but looking for work           NaN                 NaN
# 2  Not employed, but looking for work           NaN                 NaN
#
#   CodeWriter CareerSwitcher  CurrentJobTitleSelect TitleFit  \
# 0        Yes            NaN  DBA/Database Engineer     Fine
# 1        NaN            NaN                    NaN      NaN
# 2        NaN            NaN                    NaN      NaN
#
#                                  CurrentEmployerType MLToolNextYearSelect  \
# ...

# %%
project['GenderSelect']=project['GenderSelect'].replace({"Non-binary, genderqueer, or gender non-conforming": "Other","A different identity":"Other"})
project.head(3)
# Out:
#   GenderSelect        Country   Age                    EmploymentStatus  \
# 0        Other            NaN   NaN                  Employed full-time
# 1       Female  United States  30.0  Not employed, but looking for work
# 2         Male         Canada  28.0  Not employed, but looking for work
#
#   StudentStatus LearningDataScience CodeWriter CareerSwitcher  \
# 0           NaN                 NaN        Yes            NaN
# 1           NaN                 NaN        NaN            NaN
# 2           NaN                 NaN        NaN            NaN
#
#    CurrentJobTitleSelect TitleFit  \
# 0  DBA/Database Engineer     Fine
# 1                    NaN      NaN
# 2                    NaN      NaN
#
#                                  CurrentEmployerType MLToolNextYearSelect  \
# 0  Employed by a company that doesn't perform adv...             SAS Base
# 1                                                NaN               Python
# ...

# %%
schema= pd.read_csv("schema.csv")
schema.head(5)
# Out:
#              Column                                           Question Asked
# 0      GenderSelect     Select your gender identity. - Selected Choice   All
# 1    GenderFreeForm  Select your gender identity. - A different ide...   All
# 2           Country          Select the country you currently live in.   All
# 3               Age                                   What's your age?   All
# 4  EmploymentStatus             What's your current employment status?   All

# %%
exchange = pd.read_csv("conversionRates.csv")
exchange.head(5)
# Out:
#    Unnamed: 0 originCountry  exchangeRate
# 0           1           USD      1.000000
# 1           2           EUR      1.195826
# 2           3           INR      0.015620
# 3           4           GBP      1.324188
# 4           5           BRL      0.321350

# %%
#exchange.rename(columns={'originCountry':'CompensationCurrency'}, inplace=True)
#exchange.head(3)

# %%
exchange.describe()
# Out:
#        Unnamed: 0  exchangeRate
# count   86.000000     86.000000
# mean    43.500000      0.281922
# std     24.969982      0.498894
# min      1.000000      0.000030
# 25%     22.250000      0.009179
# 50%     43.500000      0.057550
# 75%     64.750000      0.282506
# max     86.000000      2.652053

# %%
#project2= project.merge(exchange, on='CompensationCurrency')
#project2.head(2)

# %%
project3= pd.merge(project, exchange, how="left", left_on= 'CompensationCurrency', right_on= 'originCountry')
project3.head(4)
# Out:
#   GenderSelect        Country   Age  \
# 0        Other            NaN   NaN
# 1       Female  United States  30.0
# 2         Male         Canada  28.0
# 3         Male  United States  56.0
#
#                                     EmploymentStatus StudentStatus  \
# 0                                 Employed full-time           NaN
# 1                 Not employed, but looking for work           NaN
# 2                 Not employed, but looking for work           NaN
# 3  Independent contractor, freelancer, or self-em...           NaN
#
#   LearningDataScience CodeWriter CareerSwitcher  \
# 0                 NaN        Yes            NaN
# 1                 NaN        NaN            NaN
# 2                 NaN        NaN            NaN
# 3                 NaN        Yes            NaN
#
#               CurrentJobTitleSelect TitleFit  \
# 0             DBA/Database Engineer     Fine
# 1                               NaN      NaN
# 2                               NaN      NaN
# ...

# %%
project4 = project3.dropna(subset= ['CompensationAmount'])
project4.head(4)
# Out:
#    GenderSelect        Country   Age  \
# 3          Male  United States  56.0
# 8        Female      Australia  43.0
# 9          Male         Russia  33.0
# 11         Male          India  27.0
#
#                                      EmploymentStatus StudentStatus  \
# 3   Independent contractor, freelancer, or self-em...           NaN
# 8                                  Employed full-time           NaN
# 9                                  Employed full-time           NaN
# 11                                 Employed full-time           NaN
#
#    LearningDataScience CodeWriter CareerSwitcher  \
# 3                  NaN        Yes            NaN
# 8                  NaN        Yes            NaN
# 9                  NaN        Yes            NaN
# 11                 NaN        Yes            NaN
#
#                    CurrentJobTitleSelect TitleFit  \
# 3       Operations Research Practitioner   Poorly
# 8                       Business Analyst     Fine
# ...

# %%
project4['CompensationAmount'].isnull().sum()
# Out:
# 0

# %%
project4['CompensationAmount']= project4['CompensationAmount'].iloc[:].str.replace(',','')
# Out:
# C:\Users\MUSA\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
project4['CompensationAmount']= project4['CompensationAmount'].iloc[:].str.replace('-','')
# Out:
# C:\Users\MUSA\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
project4['CompConverted']=pd.to_numeric(project4['CompensationAmount'])
# Out:
# C:\Users\MUSA\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
project4['CompensationAmount'].isnull().sum()
#project4['exchangeRate'].isnull().sum()
# Out:
# 0

# %%
#project4.drop(project4[project4.CompensationAmount > 300000].index, inplace=True)
project4['Salary_USD']=project4['CompConverted']*project4['exchangeRate']
# Out:
# C:\Users\MUSA\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
project4.drop(project4[project4.Salary_USD > 300000].index, inplace=True)
project4.drop(project4[project4.Salary_USD == 0].index, inplace = True)
project4.head(4)
# Out:
# C:\Users\MUSA\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\MUSA\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    GenderSelect        Country    Age  \
# 3          Male  United States 56.000
# 8        Female      Australia 43.000
# 9          Male         Russia 33.000
# 11         Male          India 27.000
#
#                                      EmploymentStatus StudentStatus  \
# 3   Independent contractor, freelancer, or self-em...           NaN
# ...

# %%
project4.describe()
# Out:
#            Age  LearningCategorySelftTaught  LearningCategoryOnlineCourses  \
# count 5116.000                     5138.000                       5140.000
# mean    34.000                       33.344                         23.268
# std      9.414                       24.626                         23.390
# min      0.000                        0.000                          0.000
# 25%     27.000                       15.000                          5.000
# 50%     32.000                       30.000                         20.000
# 75%     39.000                       50.000                         33.000
# max     99.000                      100.000                        100.000
#
#        LearningCategoryWork  LearningCategoryUniversity  \
# count              5138.000                    5135.000
# mean                 20.014                      16.784
# std                  19.683                      22.310
# min                   0.000                       0.000
# ...

# %%
project4['Salary_USD'].median()
# Out:
# 53812.170000000006

# %%
project4['Salary_USD'].median()
# Out:
# 53812.170000000006

# %%
import matplotlib
matplotlib.style.use('ggplot')
pd.set_option('display.float_format', lambda x: '%.3f' % x)
project5= project4['Salary_USD'].dropna()

bins = [0, 30000, 60000, 90000, 120000, 150000, 180000, 210000, 240000, 270000, 300000,330000]
salary_bins = pd.cut(project4['Salary_USD'], bins, include_lowest=False).dropna()
#print(pd.value_counts(salary_bins,sort=False))
salary_bins.value_counts().plot(kind='bar',color = 'g')


plt.title('Salary Distribution in Data Science Industry in USD')
plt.xlabel('Salary Range')
plt.ylabel('Number of Industry Participant')

# %%
pd.crosstab(project['LanguageRecommendationSelect'],project['CurrentJobTitleSelect'],margins=True)
# Out:
# CurrentJobTitleSelect         Business Analyst  Computer Scientist  \
# LanguageRecommendationSelect
# C/C++/C#                                     8                  12
# F#                                           0                   0
# Haskell                                      0                   1
# Java                                         3                   4
# Julia                                        0                   1
# Matlab                                       5                  10
# Other                                        3                   2
# Python                                     272                 155
# R                                          189                  28
# SAS                                          8                   0
# SQL                                         51                   1
# Scala                                        5                   3
# Stata                                        0                   0
# ...

# %%
#How long have you been learning data science?
plt.figure(figsize=(9,9))
LearningTime=project['LearningDataScienceTime'].value_counts()
plt.pie(LearningTime,labels=LearningTime.index,autopct='%.0f%%')
centre_circle = plt.Circle((0,0),0.75,color='black', fc='white',linewidth=1.25)
plt.title('Learning Data Science Time Period')

# %%
language=project['LanguageRecommendationSelect'].value_counts()
language
# Out:
# Python      6941
# R           2643
# SQL          385
# C/C++/C#     307
# Matlab       238
# Java         138
# Scala         94
# SAS           88
# Other         85
# Julia         30
# Stata         28
# Haskell       17
# F#             4
# Name: LanguageRecommendationSelect, dtype: int64

# %%
x=np.arange(13)
language=project['LanguageRecommendationSelect'].value_counts()

fig, ax= plt.subplots(figsize=(10,10))
plt.bar(x,language)
plt.xticks(x, ('Python','R','SQL','C','Matlab','Java','Scala','SAS','Other','Julia','Stata','Haskell','F#'))
ax.set_title('Language Recommendation Distribution')
plt.show()

# %%
pd.crosstab(project['MajorSelect'],project['CurrentJobTitleSelect'],margins=True)
# Out:
# CurrentJobTitleSelect                               Business Analyst  \
# MajorSelect
# A health science                                                  10
# A humanities discipline                                           11
# A social science                                                  38
# Biology                                                            8
# Computer Science                                                 105
# Electrical Engineering                                            49
# Engineering (non-computer focused)                               105
# Fine arts or performing arts                                       5
# I never declared a major                                           3
# Information technology, networking, or system a...                46
# Management information systems                                    31
# Mathematics or statistics                                        101
# ...

# %%
pd.crosstab(project['FormalEducation'],project['CurrentJobTitleSelect'],margins=True)
# Out:
# CurrentJobTitleSelect                               Business Analyst  \
# FormalEducation
# Bachelor's degree                                                284
# Doctoral degree                                                   33
# I did not complete any formal education past hi...                 5
# I prefer not to answer                                             1
# Master's degree                                                  393
# Professional degree                                               43
# Some college/university study without earning a...                30
# All                                                              789
#
# CurrentJobTitleSelect                               Computer Scientist  \
# FormalEducation
# Bachelor's degree                                                   74
# Doctoral degree                                                     93
# I did not complete any formal education past hi...                   4
# ...

# %%
pd.crosstab(project['LanguageRecommendationSelect'],project['SalaryChange'],margins=True)
# Out:
# SalaryChange                  Has decreased 20% or more  \
# LanguageRecommendationSelect
# C/C++/C#                                              2
# F#                                                    0
# Haskell                                               1
# Java                                                  4
# Julia                                                 2
# Matlab                                                1
# Other                                                 2
# Python                                               67
# R                                                    24
# SAS                                                   0
# SQL                                                   3
# Scala                                                 1
# Stata                                                 1
# All                                                 108
#
# SalaryChange                  Has decreased between 6% and 19%  \
# ...

# %%
#How long have you been writing code to analyze data?

plt.figure(figsize=(9,9))
Tenure=project['Tenure'].value_counts()
plt.pie(Tenure,labels=Tenure.index,autopct='%.0f%%')
centre_circle = plt.Circle((0,0),0.75,color='black', fc='white',linewidth=1.25)
plt.title('Years of coding experience')

# %%
project5 = project4.dropna(subset= ['Tenure'])

# %%
#project5['Tenure'].str.extract('(\d\d)',expand = True)
#project5['Tenure_number']= project5['Tenure'].str.extract('(\d)', expand= True)

project5['Tenure_Year']= project5['Tenure'].str.extract('(\d+)',expand=True)
project5.head(3)
# Out:
# C:\Users\MUSA\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#   GenderSelect        Country    Age  \
# 3         Male  United States 56.000
# 8       Female      Australia 43.000
# 9         Male         Russia 33.000
#
#                                     EmploymentStatus StudentStatus  \
# 3  Independent contractor, freelancer, or self-em...           NaN
# 8                                 Employed full-time           NaN
# 9                                 Employed full-time           NaN
#
#   LearningDataScience CodeWriter CareerSwitcher  \
# 3                 NaN        Yes            NaN
# 8                 NaN        Yes            NaN
# ...

# %%
project6=project5.dropna(subset = ['Tenure_Year'])
project6.head(2)
# Out:
#   GenderSelect        Country    Age  \
# 3         Male  United States 56.000
# 8       Female      Australia 43.000
#
#                                     EmploymentStatus StudentStatus  \
# 3  Independent contractor, freelancer, or self-em...           NaN
# 8                                 Employed full-time           NaN
#
#   LearningDataScience CodeWriter CareerSwitcher  \
# 3                 NaN        Yes            NaN
# 8                 NaN        Yes            NaN
#
#               CurrentJobTitleSelect TitleFit            CurrentEmployerType  \
# 3  Operations Research Practitioner   Poorly                  Self-employed
# 8                  Business Analyst     Fine  Employed by non-profit or NGO
#
#           MLToolNextYearSelect MLMethodNextYearSelect  \
# 3                   TensorFlow            Neural Nets
# 8  Microsoft Excel Data Mining          Link Analysis
#
#   LanguageRecommendationSelect                           PublicDatasetsSelect  \
# ...

# %%
project6['Tenure_Year_N']=pd.to_numeric(project6['Tenure_Year'])
project6.Tenure_Year_N.describe()
# Out:
# C:\Users\MUSA\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# count   4702.000
# mean       4.639
# std        3.297
# min        1.000
# 25%        3.000
# 50%        3.000
# 75%        6.000
# max       10.000
# Name: Tenure_Year_N, dtype: float64

# %%
project6.groupby('LanguageRecommendationSelect')['Tenure_Year_N'].mean().plot(kind='bar')

plt.title('Survey Participant Language Preference by Years of Experience')
plt.xlabel('Language Preference')
plt.ylabel('Average Experience')

plt.show()

# %%
project6['Tenure_Year_N'].head(2)
# Out:
# 3    10
# 8     3
# Name: Tenure_Year_N, dtype: int64

# %%
project6.groupby('GenderSelect')['Tenure_Year_N'].mean().plot(kind='bar')

plt.title('Survey Participants by Gender and Years of Experience')
plt.xlabel('Gender')
plt.ylabel('Average Experience')
#plt.tight_layout(pad=0.4, w_pad=0.5, h_pad = 1)
plt.show()

# %%
y= project6['Salary_USD']
x= project6['Age']

plt.scatter(x,y)

plt.title('Salary Distribution by Age')
plt.xlabel('Age')
plt.ylabel('Salary in USD')

# %%
y= project6['Salary_USD']
x= project6['Tenure_Year_N']

plt.scatter(x,y)

plt.title('Salary Distribution by Years of Experience')
plt.xlabel('Years of Experience')
plt.ylabel('Salary in USD')

# %%
#Seaborn Density plot
sns.kdeplot(project6['Salary_USD'], shade=True)
# Out:
# C:\Users\MUSA\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:454: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X>clip[0], X<clip[1])] # won't work for two columns.
# C:\Users\MUSA\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:454: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X>clip[0], X<clip[1])] # won't work for two columns.

# %%
# Seaborn Violinplot
sns.violinplot(y=project6["Salary_USD"])

# %%
# Seaborn Violinplot
sns.violinplot(y=project6['LanguageRecommendationSelect'],x=project6['Salary_USD'],gridsize=150,width=1.0,scale='area', bw=0.1)

# %%
# Seaborn Violinplot
sns.violinplot(y=project6['LanguageRecommendationSelect'],x=project6['Salary_USD'],gridsize=150,width=0.9,scale='count')

# %%
# Seaborn Violinplot
sns.violinplot(y=project6['CurrentJobTitleSelect'],x=project6['Salary_USD'],gridsize=150,width=1.0, scale='count', bw=0.1)

# %%
# Seaborn Violinplot
sns.violinplot(y=project6['FormalEducation'],x=project6['Salary_USD'],gridsize=150,width=0.9,scale='count', bw=0.1)
